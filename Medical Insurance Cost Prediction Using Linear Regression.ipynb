# %% [markdown]
# # Medical Insurance Cost Prediction Using Linear Regression

# %% [markdown]
# _______________________________
#
# ## Overview
# This project focuses on predicting medical insurance costs based on a variety of factors, including age, gender, BMI, number of children, smoking status, and region of residence. Using Python's data analysis libraries, the dataset was examined, cleaned, and visualized to explore patterns that impact insurance charges. After preprocessing the data, a Linear Regression model was developed to predict insurance costs, which could be used by insurance companies to assess potential charges based on personal attributes. The model's performance was evaluated using the R-squared metric to ensure reliable predictions on new data.

# %% [markdown]
# ## The project code:

# %% [markdown]
# ### 1.  Importing the Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ### 2.  Data Collection & Analysis

# %% [markdown]
# #### a- Loading the data from csv file to a Pandas DataFrame:

# %%
# loading the data from csv file to a Pandas DataFrame
insurance_dataset = pd.read_csv('/kaggle/input/insurance-csv/insurance.csv')

# %% [markdown]
# #### b- Showing first 5 rows of the dataframe:

# %%
# first 5 rows of the dataframe
insurance_dataset.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# #### c- Showing number of rows and columns:

# %%
# number of rows and columns
insurance_dataset.shape
# Out:
# (1338, 7)

# %% [markdown]
# #### d- Getting some informations about the dataset:

# %%
# getting some informations about the dataset
insurance_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# **Categorical Features:**
# - Sex
# - Smoker
# - Region

# %% [markdown]
# #### e- Checking for missing values:

# %%
# checking for missing values
insurance_dataset.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %% [markdown]
# #### f- Statistical Measures of the dataset:

# %%
# statistical Measures of the dataset
insurance_dataset.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %% [markdown]
# #### g- Distribution of age value:

# %%
# distribution of age value
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(insurance_dataset['age'])
plt.title('Age Distribution')
plt.show()
# Out:
# <ipython-input-8-28228e9c3528>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance_dataset['age'])
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### h- Showing gender distribution:

# %%
# Gender column
plt.figure(figsize=(6,6))
sns.countplot(x='sex', data=insurance_dataset)
plt.title('Sex Distribution')
plt.show()

# %%
insurance_dataset['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %% [markdown]
# #### i- Showing the BMI distribution:

# %%
# bmi distribution
plt.figure(figsize=(6,6))
sns.distplot(insurance_dataset['bmi'])
plt.title('BMI Distribution')
plt.show()
# Out:
# <ipython-input-11-81b69896b0d5>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance_dataset['bmi'])
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Normal BMI Range is from 18.5 to 24.9

# %% [markdown]
# #### j- Showing children variable details:

# %%
# children column
plt.figure(figsize=(6,6))
sns.countplot(x='children', data=insurance_dataset)
plt.title('Children')
plt.show()

# %%
insurance_dataset['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %% [markdown]
# #### k- Showing smoker variable details:

# %%
# smoker column
plt.figure(figsize=(6,6))
sns.countplot(x='smoker', data=insurance_dataset)
plt.title('smoker')
plt.show()

# %%
insurance_dataset['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %% [markdown]
# #### l- Showing the different regions:

# %%
# region column
plt.figure(figsize=(6,6))
sns.countplot(x='region', data=insurance_dataset)
plt.title('region')
plt.show()

# %%
insurance_dataset['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %% [markdown]
# #### m- Distribution of expenses value:

# %%
# distribution of expenses value
plt.figure(figsize=(6,6))
sns.distplot(insurance_dataset['expenses'])
plt.title('Expenses Distribution')
plt.show()
# Out:
# <ipython-input-18-65bf4ad3e653>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(insurance_dataset['expenses'])
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 3.  Data Pre-Processing

# %% [markdown]
# #### a- Encoding the categorical features:

# %%
# encoding sex column
insurance_dataset.replace({'sex':{'male':0,'female':1}}, inplace=True)

3 # encoding 'smoker' column
insurance_dataset.replace({'smoker':{'yes':0,'no':1}}, inplace=True)

# encoding 'region' column
insurance_dataset.replace({'region':{'southeast':0,'southwest':1,'northeast':2,'northwest':3}}, inplace=True)
# Out:
# <ipython-input-19-7d5826986d65>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   insurance_dataset.replace({'sex':{'male':0,'female':1}}, inplace=True)
# <ipython-input-19-7d5826986d65>:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   insurance_dataset.replace({'smoker':{'yes':0,'no':1}}, inplace=True)
# ...

# %%
insurance_dataset.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    1  27.9         0       0       1  16884.92
# 1   18    0  33.8         1       1       0   1725.55
# 2   28    0  33.0         3       1       0   4449.46
# 3   33    0  22.7         0       1       3  21984.47
# 4   32    0  28.9         0       1       3   3866.86

# %% [markdown]
# #### b- Splitting the Features and Target:

# %%
X = insurance_dataset.drop(columns='expenses', axis=1)
Y = insurance_dataset['expenses']

# %%
print(X)
# Out:
#       age  sex   bmi  children  smoker  region
# 0      19    1  27.9         0       0       1
# 1      18    0  33.8         1       1       0
# 2      28    0  33.0         3       1       0
# 3      33    0  22.7         0       1       3
# 4      32    0  28.9         0       1       3
# ...   ...  ...   ...       ...     ...     ...
# 1333   50    0  31.0         3       1       3
# 1334   18    1  31.9         0       1       2
# 1335   18    1  36.9         0       1       0
# 1336   21    1  25.8         0       1       1
# 1337   61    1  29.1         0       0       3
#
# [1338 rows x 6 columns]

# %%
print(Y)
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# 1337    29141.36
# Name: expenses, Length: 1338, dtype: float64

# %% [markdown]
# #### c- Splitting the data into Training set & Testing set:

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1338, 6) (1070, 6) (268, 6)

# %% [markdown]
# ### 4.  Model Training

# %% [markdown]
# #### a- Linear Regression Model:

# %%
# loading the Linear Regression model
regressor = LinearRegression()

# %%
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### b- Model Evaluation:

# %%
# prediction on training data
training_data_prediction =regressor.predict(X_train)

# %%
# R squared value
r2_train = metrics.r2_score(Y_train, training_data_prediction)
print('R squared vale : ', r2_train)
# Out:
# R squared vale :  0.7515233180624387

# %%
# prediction on test data
test_data_prediction =regressor.predict(X_test)

# %%
# R squared value
r2_test = metrics.r2_score(Y_test, test_data_prediction)
print('R squared vale : ', r2_test)
# Out:
# R squared vale :  0.7447382074449775

# %% [markdown]
# #### c- Real Case scenario:

# %%
input_data = (31,1,25.74,0,1,0)

# changing input_data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = regressor.predict(input_data_reshaped)
print(prediction)

print('The insurance cost is USD ', prediction[0])
# Out:
# [3759.33603725]
# The insurance cost is USD  3759.3360372503557
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# _____________________________
#
# ## Conclusion
# The project successfully demonstrated a predictive system for estimating medical insurance costs based on demographic and lifestyle attributes. Linear Regression proved effective for this dataset, yielding high R-squared values that indicate a strong fit to the data. The system highlights the importance of certain factors, like BMI and smoking status, in influencing insurance charges, consistent with industry standards. Future improvements might involve exploring additional machine learning algorithms or refining input features to increase prediction accuracy and adapt to more varied data.
